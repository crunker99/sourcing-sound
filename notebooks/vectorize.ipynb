# %%
import clean_data

# %%
run clean_data
# Out:
# How many train files to process? 500
# 0   Church_bell
# /Users/jared/anaconda3/lib/python3.7/site-packages/librosa/filters.py:235: UserWarning: Empty filters detected in mel frequency basis. Some channels will produce empty responses. Try increasing your sampling rate (and fmax) or reducing n_mels.
#   warnings.warn('Empty filters detected in mel frequency basis. '
# 1   Frying_(food)
# 2   Computer_keyboard
# 3   Scissors
# 4   Purr
# 5   Gasp
# 6   Applause,Cheering
# 7   Applause,Crowd,Cheering
# 8   Applause,Cheering
# 9   Applause,Cheering
# 10   Applause,Crowd,Cheering
# 11   Applause,Cheering
# 12   Sink_(filling_or_washing),Water_tap_and_faucet
# 13   Tap
# 14   Computer_keyboard
# 15   Zipper_(clothing)
# 16   Stream
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ...
